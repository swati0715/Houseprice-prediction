# %% [markdown]
# <a href="https://colab.research.google.com/github/swati0715/Houseprice-prediction/blob/main/cv_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ee3a4bdd-d4e0-4730-ad9a-0992982863a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee3a4bdd-d4e0-4730-ad9a-0992982863a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename=list(uploaded.keys())[0]
img=cv2.imread(filename)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=171x295>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=171x295>

# %%
a=[img,gray]
for i in a:
 resized=cv2.resize(i,(300,300))
 cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=L size=300x300>

# %%
# Draw rectangle & text
annotated=img.copy()
cv2.rectangle(annotated,(50,50),(250,250),(0,0,255),3)
cv2.putText(annotated,'My Box',(60,45),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),2)
cv2_imshow(annotated)
# Out:
# <PIL.Image.Image image mode=RGB size=171x295>

# %%
cv2.imwrite('output_img.png',annotated)
print("Image saved as output_img.jpg")
# Out:
# Image saved as output_img.jpg

# %% [markdown]
# next project:Data agumentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array

# %%
uploaded=files.upload()
filename=list(uploaded.keys())
# Out:
#      <input type="file" id="files-acea67fb-7c9c-449a-8fc6-f21816d57af1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acea67fb-7c9c-449a-8fc6-f21816d57af1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded=files.upload()
filename=list(uploaded.keys())[0] # Select the first element of the list
# %%

# %%
img=load_img(filename,target_size=(224,224)) # Pass the filename string to load_img
img_array=img_to_array(img)
img_array=np.expand_dims(img_array,axis=0)
# Out:
#      <input type="file" id="files-16174aa4-440e-4362-9f77-5173e3170f65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16174aa4-440e-4362-9f77-5173e3170f65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datagen=ImageDataGenerator(
    rotation_range=30,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # shear_range=0.2,
    # zoom_range=0.2,
    # horizontal_flip=True,
    # brightness_range=[0.5,1.5]

)
#generate augmented images
i = 0
for batch in datagen.flow(img_array, batch_size=1):
    plt.figure(figsize=(2,2))
    plt.imshow(batch[0].astype('uint8'))
    plt.axis('off')
    i += 1
    if i > 5:
        break
